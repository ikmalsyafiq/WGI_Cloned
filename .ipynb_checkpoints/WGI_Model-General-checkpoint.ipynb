# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import math
import shap
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Read Data

# %%
## Read Clean Data From Folder
path = r'C_data'
db_dir = glob.glob(path + "/*.csv")

li = []

for i in db_dir:
    df = pd.read_csv(i, index_col=None, header=0)
    li.append(df)
ori_db = pd.concat(li, ignore_index=True)
wtpc = pd.read_csv('Design Capacity WTP.csv')
master_db = pd.merge(ori_db,wtpc[['wtp','Water Source','Lembangan']],on='wtp',how='left')
master_db['Date'] = pd.to_datetime(master_db['Date'])

# %% [markdown]
# ### General Data Cleaning

# %%
## Define Outliers Removal Function
def is_outlier(s):
    lower_limit = s.mean() - (s.std() * 1.5)
    upper_limit = s.mean() + (s.std() * 1.5)
    return ~s.between(lower_limit, upper_limit)

# %%
## Rate of change variables ("..._chpctm") vs agaisnt median value of respective WTP
tv = ['Disinfectant_chpctm','pH Adjuster_chpctm','Coagulant_chpctm']
idv = ['pH_avg_chpctm', 'Turbidity_avg_chpctm','Color_avg_chpctm', 'Iron_avg_chpctm', 'Ammonia_avg_chpctm', 'Manganese_avg_chpctm']
master_db[idv] = master_db[idv].fillna(0)
to_c5 = master_db.copy()
to_c5 = to_c5[tv+idv+['Lembangan','wtp','Date']].copy()
to_c5 = to_c5[~to_c5.isin([np.inf, -np.inf]).any(1)].copy()
to_c5 = to_c5.dropna()
ge2 = tv + idv

# %%
opp = pd.DataFrame()
for i in ge2:
    
    if i==ge2[0]:
        m0 = to_c5[~to_c5.groupby(['Lembangan','wtp'])[i].apply(is_outlier)][['Lembangan','wtp',i,'Date']]
        opp = opp.append(m0)
    else:
        m1 = to_c5[~to_c5.groupby(['Lembangan','wtp'])[i].apply(is_outlier)][['Lembangan','wtp',i,'Date']]
        opp = pd.merge(opp,m1,on=['Lembangan','wtp','Date'],how='left')

# %%
opp = opp.dropna()
opp.shape
# Out:
# (3913, 12)

# %% [markdown]
# ## Modelling (Feature Importance)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sys import stdout
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble  import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor

# %%
## Random Forest Optimization
def rfopt(Xr_train,y_train,Xr_test,y_test):
    score = {"fea":[],"rscore":[],"MSE":[]}
    max_depth = [10, 20, 30, 40]
    n_estimators = [100, 200, 300]
    for i in max_depth:
        
        for j in n_estimators:
            rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=j, max_depth=i, random_state=0)).fit(Xr_train, y_train)
            rs = round(rf.score(Xr_train,y_train)*100,2)
            rf_pr = rf.predict(Xr_test)
            ms = round(mean_squared_error(y_test,rf_pr),2)
            score["fea"].append(f"max_depth{i} n_est:{j}")
            score["rscore"].append(rs)
            score["MSE"].append(ms)
            del rf
            gc.collect()
    return score

# %% [markdown]
# ## Sungai Langat

# %%
wwt = 'Sg Langat'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   80.39  161.80  12.720063
# 1   max_depth10 n_est:200   80.48  159.64  12.634872
# 2   max_depth10 n_est:300   80.42  157.28  12.541132
# 3   max_depth20 n_est:100   89.78  161.45  12.706298
# 4   max_depth20 n_est:200   89.88  160.43  12.666096
# 5   max_depth20 n_est:300   89.93  158.05  12.571794
# 6   max_depth30 n_est:100   90.07  162.10  12.731850
# 7   max_depth30 n_est:200   90.16  160.17  12.655829
# 8   max_depth30 n_est:300   90.17  157.53  12.551096
# 9   max_depth40 n_est:100   90.08  161.94  12.725565
# 10  max_depth40 n_est:200   90.17  160.14  12.654643
# 11  max_depth40 n_est:300   90.18  157.43  12.547111

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.175919            0.119862
# 1  Turbidity_avg_chpctm             0.132744            0.181573
# 2      Color_avg_chpctm             0.117007            0.125893
# 3       Iron_avg_chpctm             0.187991            0.136230
# 4    Ammonia_avg_chpctm             0.273259            0.171487
# 5  Manganese_avg_chpctm             0.113079            0.264956
#
#    Coagulant_chpctm
# 0          0.098742
# 1          0.382960
# 2          0.136235
# 3          0.162029
# 4          0.117965
# 5          0.102069
# R Square Result 89.93%
# MSE 158.05

# %% [markdown]
# ## Sg Klang

# %%
wwt = 'Sg Klang'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   86.39  166.23  12.893021
# 1   max_depth10 n_est:200   86.70  164.38  12.821076
# 2   max_depth10 n_est:300   86.64  163.46  12.785148
# 3   max_depth20 n_est:100   90.45  167.92  12.958395
# 4   max_depth20 n_est:200   90.96  166.72  12.912010
# 5   max_depth20 n_est:300   90.98  165.32  12.857683
# 6   max_depth30 n_est:100   90.42  167.64  12.947587
# 7   max_depth30 n_est:200   90.95  166.41  12.900000
# 8   max_depth30 n_est:300   90.98  165.09  12.848735
# 9   max_depth40 n_est:100   90.42  167.64  12.947587
# 10  max_depth40 n_est:200   90.95  166.44  12.901163
# 11  max_depth40 n_est:300   90.98  165.10  12.849124

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.399563            0.254830
# 1  Turbidity_avg_chpctm             0.162903            0.383438
# 2      Color_avg_chpctm             0.116860            0.149382
# 3       Iron_avg_chpctm             0.171916            0.101805
# 4    Ammonia_avg_chpctm             0.131418            0.094929
# 5  Manganese_avg_chpctm             0.017341            0.015616
#
#    Coagulant_chpctm
# 0          0.212753
# 1          0.432813
# 2          0.237262
# 3          0.060043
# 4          0.053190
# 5          0.003939
# R Square Result 90.98%
# MSE 165.32

# %% [markdown]
# ## Sg Selangor

# %%
wwt = 'Sg Selangor'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   72.15  171.18  13.083577
# 1   max_depth10 n_est:200   72.37  171.41  13.092364
# 2   max_depth10 n_est:300   72.34  170.74  13.066752
# 3   max_depth20 n_est:100   87.45  177.26  13.313903
# 4   max_depth20 n_est:200   87.68  177.16  13.310147
# 5   max_depth20 n_est:300   87.74  175.76  13.257451
# 6   max_depth30 n_est:100   88.15  177.32  13.316156
# 7   max_depth30 n_est:200   88.41  177.74  13.331917
# 8   max_depth30 n_est:300   88.48  176.45  13.283448
# 9   max_depth40 n_est:100   88.19  177.52  13.323663
# 10  max_depth40 n_est:200   88.41  177.55  13.324789
# 11  max_depth40 n_est:300   88.48  176.17  13.272905

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.160298            0.165444
# 1  Turbidity_avg_chpctm             0.234592            0.236591
# 2      Color_avg_chpctm             0.229408            0.220563
# 3       Iron_avg_chpctm             0.151441            0.137598
# 4    Ammonia_avg_chpctm             0.128607            0.152120
# 5  Manganese_avg_chpctm             0.095655            0.087685
#
#    Coagulant_chpctm
# 0          0.112553
# 1          0.406347
# 2          0.202814
# 3          0.107380
# 4          0.096083
# 5          0.074823
# R Square Result 87.74%
# MSE 175.76

# %% [markdown]
# ## Sg Semantan

# %%
wwt = 'Sg Semantan'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   92.34  235.28  15.338840
# 1   max_depth10 n_est:200   92.57  231.12  15.202631
# 2   max_depth10 n_est:300   92.66  234.21  15.303921
# 3   max_depth20 n_est:100   92.60  235.87  15.358060
# 4   max_depth20 n_est:200   92.79  232.89  15.260734
# 5   max_depth20 n_est:300   92.85  235.16  15.334927
# 6   max_depth30 n_est:100   92.60  235.96  15.360990
# 7   max_depth30 n_est:200   92.79  232.96  15.263027
# 8   max_depth30 n_est:300   92.85  235.13  15.333949
# 9   max_depth40 n_est:100   92.60  235.96  15.360990
# 10  max_depth40 n_est:200   92.79  232.96  15.263027
# 11  max_depth40 n_est:300   92.85  235.13  15.333949

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.101331            0.198427
# 1  Turbidity_avg_chpctm             0.198753            0.087015
# 2      Color_avg_chpctm             0.197325            0.168114
# 3       Iron_avg_chpctm             0.376189            0.447966
# 4    Ammonia_avg_chpctm             0.043138            0.042302
# 5  Manganese_avg_chpctm             0.083264            0.056176
#
#    Coagulant_chpctm
# 0          0.251155
# 1          0.375729
# 2          0.081811
# 3          0.168532
# 4          0.060287
# 5          0.062486
# R Square Result 92.85%
# MSE 235.16

# %% [markdown]
# ## Sg Tengi

# %%
wwt = 'Sg Tengi'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   92.40  184.17  13.570925
# 1   max_depth10 n_est:200   92.31  182.49  13.508886
# 2   max_depth10 n_est:300   92.42  182.91  13.524422
# 3   max_depth20 n_est:100   92.79  185.44  13.617636
# 4   max_depth20 n_est:200   92.78  183.33  13.539941
# 5   max_depth20 n_est:300   92.88  184.06  13.566871
# 6   max_depth30 n_est:100   92.79  185.40  13.616167
# 7   max_depth30 n_est:200   92.78  183.32  13.539572
# 8   max_depth30 n_est:300   92.88  184.05  13.566503
# 9   max_depth40 n_est:100   92.79  185.40  13.616167
# 10  max_depth40 n_est:200   92.78  183.32  13.539572
# 11  max_depth40 n_est:300   92.88  184.05  13.566503

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.135761            0.345855
# 1  Turbidity_avg_chpctm             0.154864            0.229259
# 2      Color_avg_chpctm             0.256303            0.255068
# 3       Iron_avg_chpctm             0.220415            0.065857
# 4    Ammonia_avg_chpctm             0.168396            0.060100
# 5  Manganese_avg_chpctm             0.064261            0.043861
#
#    Coagulant_chpctm
# 0          0.043659
# 1          0.801696
# 2          0.078074
# 3          0.039963
# 4          0.025918
# 5          0.010691
# R Square Result 92.88%
# MSE 184.06

# %% [markdown]
# ## Sg Bernam

# %%
wwt = 'Sg Bernam'
## Common Target
to_c7 = opp[opp['Lembangan']==wwt].copy()
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   88.15  601.53  24.526109
# 1   max_depth10 n_est:200   88.23  612.76  24.753990
# 2   max_depth10 n_est:300   88.22  613.88  24.776602
# 3   max_depth20 n_est:100   93.21  609.18  24.681572
# 4   max_depth20 n_est:200   93.29  619.78  24.895381
# 5   max_depth20 n_est:300   93.34  617.96  24.858801
# 6   max_depth30 n_est:100   93.23  605.74  24.611786
# 7   max_depth30 n_est:200   93.34  616.16  24.822570
# 8   max_depth30 n_est:300   93.37  615.90  24.817333
# 9   max_depth40 n_est:100   93.23  605.74  24.611786
# 10  max_depth40 n_est:200   93.34  616.16  24.822570
# 11  max_depth40 n_est:300   93.37  615.90  24.817333

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.599769            0.628765
# 1  Turbidity_avg_chpctm             0.097713            0.054762
# 2      Color_avg_chpctm             0.095514            0.141124
# 3       Iron_avg_chpctm             0.085270            0.058091
# 4    Ammonia_avg_chpctm             0.061455            0.077916
# 5  Manganese_avg_chpctm             0.060278            0.039343
#
#    Coagulant_chpctm
# 0          0.260417
# 1          0.124542
# 2          0.350042
# 3          0.110012
# 4          0.084328
# 5          0.070659
# R Square Result 93.34%
# MSE 617.96

# %% [markdown]
# ## General

# %%
to_c7 = opp.copy()
to_c7.shape
## Common Target
y = to_c7[tv].copy()
X = to_c7[idv].copy()
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=88)
# Out:
# (3913, 12)

# %%
rfoptsc = rfopt(X_train,y_train,X_test,y_test)
cal = pd.DataFrame(rfoptsc)
cal['Error'] = np.sqrt(cal['MSE'])
cal
# Out:
#                       fea  rscore     MSE      Error
# 0   max_depth10 n_est:100   59.31  238.76  15.451861
# 1   max_depth10 n_est:200   59.47  238.23  15.434701
# 2   max_depth10 n_est:300   59.57  237.40  15.407790
# 3   max_depth20 n_est:100   85.60  238.14  15.431785
# 4   max_depth20 n_est:200   85.88  236.87  15.390582
# 5   max_depth20 n_est:300   86.00  236.50  15.378556
# 6   max_depth30 n_est:100   89.62  239.63  15.479987
# 7   max_depth30 n_est:200   89.91  238.27  15.435997
# 8   max_depth30 n_est:300   90.01  238.06  15.429193
# 9   max_depth40 n_est:100   89.79  240.35  15.503225
# 10  max_depth40 n_est:200   90.10  238.42  15.440855
# 11  max_depth40 n_est:300   90.21  238.11  15.430813

# %%
max_depth = 20
rf = MultiOutputRegressor(RandomForestRegressor(n_estimators=300, max_depth=max_depth, random_state=0)).fit(X_train, y_train)
rf_pr = rf.predict(X_test)
rfdic = [
rf.estimators_[0].feature_importances_,
rf.estimators_[1].feature_importances_,
rf.estimators_[2].feature_importances_]

# %%
rap = pd.DataFrame({'Feature':X_train.columns})
RDF = pd.DataFrame(rfdic).T
RDF = RDF.rename(columns=dict(zip(RDF.columns,tv)))
RDF = pd.concat([rap,RDF],axis=1)
RDF
print(f"R Square Result {round(rf.score(X_train,y_train)*100,2)}%")
print(f"MSE {round(mean_squared_error(y_test,rf_pr),2)}")
# Out:
#                 Feature  Disinfectant_chpctm  pH Adjuster_chpctm  \
# 0         pH_avg_chpctm             0.219372            0.364929
# 1  Turbidity_avg_chpctm             0.186893            0.133443
# 2      Color_avg_chpctm             0.151664            0.168518
# 3       Iron_avg_chpctm             0.185382            0.117870
# 4    Ammonia_avg_chpctm             0.134832            0.108283
# 5  Manganese_avg_chpctm             0.121857            0.106957
#
#    Coagulant_chpctm
# 0          0.297287
# 1          0.182755
# 2          0.252931
# 3          0.085753
# 4          0.089673
# 5          0.091601
# R Square Result 86.0%
# MSE 236.5

# %%
## User Defined Weightage for each Chemical Products

## General Random Method
weight = np.array([0.3, 0.3, 0.4])

## Weightage Based on Cost
weight_c = np.array([0.395, 0.1224, 0.4826])

## Weightage Based on Dosing 
weight_d = np.array([0.1064, 0.1969, 0.6967])

# %%
## Refined Weightage
fw = RDF.iloc[:,1:].dot(weight)
fwc = RDF.iloc[:,1:].dot(weight_c)
fwd = RDF.iloc[:,1:].dot(weight_d) # (Will be focus on this as user has agreed on this weightage)

# %% [markdown]
# ## Scoring Mechanism & Generate Water Grading

# %%
path = r'WQ\Refined'
db_dir = glob.glob(path + "/*.csv")

li = []

for i in db_dir:
    df = pd.read_csv(i, index_col=None, header=0)
    li.append(df)
fdb = pd.concat(li, ignore_index=True)
fdb = fdb.drop(['Unnamed: 0'],axis=1)
fdb['Date'] = pd.to_datetime(fdb['Date'])
cl = fdb.loc[:, fdb.dtypes == object].columns.to_list()
cl.remove('wtp')
for i in cl:
    fdb[i] = fdb[i].fillna(9999)
    fdb[i] = fdb[i].apply(lambda x: str(x).replace(',',''))
fdb[cl] = fdb[cl].apply(pd.to_numeric)
db = fdb.copy()
avg = fdb.columns
l = ['Quarter','wtp','Month','Date']
avg = [x for x in avg if "avg" in x ] + l
db['Month'] = db['Date'].dt.month
db['Quarter'] = db['Date'].dt.quarter
dc = db[avg].copy()
dc= dc.drop(['Aluminium_avg', 'Fluoride_avg'],axis=1)
avc = [x for x in dc.columns if "avg" in x ]
wtpc = pd.read_csv('Design Capacity WTP.csv')
dc = pd.merge(dc,wtpc[['wtp','Water Source','Lembangan']],on='wtp',how='left')
dc = dc[dc['pH_avg']<14].copy()

# %% [markdown]
# ### Water Grading Mechanism

# %%
## Ammonia

def ammonia_score(x):
    if x<=0.3:
        score = 100.5-105*x
    elif (x>0.3) & (x<=4):
        score = 94*math.exp(-0.573*x)-5*abs(x-2)
    else:
        score = 0
        
    return score

## Suspended Solid (Turbidity)

def SS_score(x):
    if x<=100:
        score = 97.5*math.exp(-0.00676*x)+0.05*x
    elif (x>100) & (x<=1000):
        ### what is I
        score = 71*math.exp(-0.0061*x)+0.015*x
    else:
        score = 0
        
    return score

## pH Score

def pH_score(x):
    if x<5.5:
        score = 17.02-17.2*x+5.02*x**2
    elif (x>=5.5) & (x<7):
        score = -242+95.5*x-6.67*x**2
    elif (x>=7) & (x<8.75):
        score = -181+82.4*x-6.05*x**2
    else:
        score = 536-77.0*x+2.76*x**2
        
    return score

## Color Score (National Water Standard for Malaysia Guideline)

def color_score(x):
    # Class I - Practically no treatment necessary.
    if x<15:
        score = (1-x/15)*10+90
    # Class II - Conventional treatment
    elif (x>=15) & (x<=150):
        score = (1-(x-15)/135)*90
    # Class III and lower - Extensive treatment required
    else:
        score = 0
        
    return score

## Manganese Score (National Water Standard for Malaysia Guideline)
def Mn_score(x):
    # Class I
    if x<0.1:
        score = (1-x/0.1)*50+50
    # Class II & III
    elif (x>=0.1) & (x<=0.2):
        score = (1-(x-0.1)/0.1)*50
    # Class IV
    else:
        score = 0
    return score


## Iron Score 
def Fe_score(x):
    # WQ Dept Excel file guideline
    fegl = 1
    score = max((1 - x/fegl)*100,0)
    return score

# %%
to_score = dc[['wtp', 'pH_avg', 'Date', 'Turbidity_avg', 'Color_avg', 'Iron_avg','Ammonia_avg','Manganese_avg','Month']].copy()
to_score['pH_Sc'] = to_score['pH_avg'].apply(lambda x: pH_score(x))
to_score['SS_sc'] = to_score['Turbidity_avg'].apply(lambda x: SS_score(x))
to_score['Co_Sc'] = to_score['Color_avg'].apply(lambda x: color_score(x))
to_score['Iron_Sc'] = to_score['Iron_avg'].apply(lambda x: Fe_score(x))
to_score['Amm_Sc'] = to_score['Ammonia_avg'].apply(lambda x: ammonia_score(x))
to_score['Mgn_Sc'] = to_score['Manganese_avg'].apply(lambda x: Mn_score(x))

# %%
Psc = ['pH_Sc','SS_sc','Co_Sc','Iron_Sc','Amm_Sc','Mgn_Sc']

# %%
## Water Grading by Random Weightage
to_score['WGI'] = to_score[Psc].dot(np.array(fw))

## Water Grading by Cost Weightage
to_score['WGI_c'] = to_score[Psc].dot(np.array(fwc))

## Water Grading by Dosage Weightage
to_score['WGI_d'] = to_score[Psc].dot(np.array(fwd))

# %% [markdown]
# ## Water Grading Mechanism/Model Evaluation (VS WQI)

# %%
## Get WQI data provided by production team 
wqidb = pd.read_csv('WQI_Breakdown.csv')
wqidb = wqidb.rename(columns={'Month':'DMonth','New WTP':'wtp'})
wqidb['DMonth'] = pd.to_datetime(wqidb['DMonth'])
wqidb['Month'] = wqidb['DMonth'].dt.month

# %%
## Touch up on raw data
def ren(x):
    if x=='Semenyih 2 ':
        y = 'Semenyih 2'
    else:
        y = x
    return y

# %%
fscore = to_score.groupby(['wtp','Month'])['pH_Sc', 'SS_sc', 'Co_Sc','Iron_Sc', 'Amm_Sc', 'Mgn_Sc', 'WGI','WGI_c','WGI_d'].mean().reset_index()
fscore['wtp'] = fscore['wtp'].apply(lambda x: ren(x))
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
## Final data to be compare 
c = pd.merge(fscore, wqidb, on=['wtp','Month'],how='left')

## To gauge roughly how much the differences
c['Diff'] = abs(c['WGI_d'] - c['WQI'])

# %%
## For user to double check the grading by WTP
c.to_excel('WGI_Full_DB.xlsx')

# %%
to_merge = dc[['Lembangan','wtp']].drop_duplicates(subset='wtp')
c = pd.merge(c,to_merge,on=['wtp'],how='left')

# %%
## General Plot to see how the WQI & WGI Differences
for i in c['wtp'].unique():
    c[c['wtp']==i].plot(x='Month',y=['WGI','WQI'])
    plt.title(f'WGI VS WQI Time Series {i}')
    plt.ylabel('Score')
    plt.show()
# Out:
# Text(0.5, 1.0, 'WGI VS WQI Time Series Ampang Intake')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Batang Kali')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Bernam River Headworks (New)')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Bernam River Headworks (Old)')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Bukit Nanas')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Bukit Tampoi New')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Cheras Batu 11')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Kalumpang')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Kepong')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Kuala Kubu Bharu')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Labohan Dagang')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Langat 2')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series North Hummock')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Rantau Panjang New')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Rantau Panjang Old')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Rasa')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Salak Tinggi')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Semenyih 2')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Batu')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Dusun')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Gombak')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Labu')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Langat')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Lolo - Baru')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Pangsoon')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Rangkap')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Rumput')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Selangor Fasa 1')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Selangor Fasa 2 Stream C')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Selangor Fasa 3')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Selisek')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Semenyih')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Serai')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Sireh')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Sungai Tengi')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'WGI VS WQI Time Series Wangsa Maju')
# Text(0, 0.5, 'Score')

# %% [markdown]
# ### WGI/WQI VS Actual Monthly Chemical Consumption (Linear Correlation)

# %%
## Loading Chemical File & Perform Data Regrouping
chedf = pd.read_csv('checons.csv')
chedf = chedf.rename(columns={'Flopam AH 912 PWG (25kg / bag).1':'Flopam AH 912 PWG (25kg / bag)'})
mdict = dict(zip(chedf['Month'].unique(),np.array(range(1,13,1))))
chedf['Month'] = chedf['Month'].apply(lambda x: mdict.get(x))
cgr = pd.read_csv("C.Grouping.csv")
cgr = cgr.rename(columns={'Chemical Name':'Chem'})

# %%
newdb = pd.merge(pd.DataFrame({'Chem':chedf.columns}),cgr,on='Chem',how='inner')
coa = newdb[newdb['Correct Grouping']=='Coagulant']['Chem'].unique()
pha = newdb[newdb['Correct Grouping']=='pH Adjuster']['Chem'].unique()
dis = newdb[newdb['Correct Grouping']=='Disinfectant']['Chem'].unique()

# %%
chedf['Coagulant'] = chedf[coa].sum(axis=1)
chedf['pH Adjuster'] = chedf[pha].sum(axis=1)
chedf['Disinfectant'] = chedf[dis].sum(axis=1)

# %%
fcl = ['Month', 'wtp', 'Coagulant','pH Adjuster', 'Disinfectant']
db1 = chedf[fcl].copy()
c2 = pd.merge(c,db1,on=['wtp','Month'],how='left')

# %%
## General Correlation Between Chemical Products & WGI/WQI
c2[['wtp','WQI','WGI_d','Coagulant','Disinfectant','pH Adjuster']].corr()
# Out:
#                    WQI     WGI_d  Coagulant  Disinfectant  pH Adjuster
# WQI           1.000000  0.366011  -0.159966     -0.168895    -0.201372
# WGI_d         0.366011  1.000000  -0.125984     -0.118328    -0.144047
# Coagulant    -0.159966 -0.125984   1.000000      0.945101     0.957599
# Disinfectant -0.168895 -0.118328   0.945101      1.000000     0.959291
# pH Adjuster  -0.201372 -0.144047   0.957599      0.959291     1.000000

# %% [markdown]
# ### WGI/WQI VS Actual Monthly Chemical Consumption (Elasticity of Grading)

# %%
the_name = ['pH_Sc', 'SS_sc', 'Co_Sc', 'Iron_Sc', 'Amm_Sc', 'Mgn_Sc', 'WGI','SIpH', 'SIDO', 'SISS', 'SIBOD', 'SICOD', 'SIAN','WQI','WGI_c','WGI_d', 'pH Adjuster', 'Disinfectant', 'Coagulant']
## Generate Daily % Changed 
for i in the_name:
    c2[f'{i}_chpctm'] = (c2.groupby('wtp')[i].shift(1)-c2[i])/c2[i]
    
## Parameters To Focus
tfi2 = ['pH Adjuster_chpctm','Disinfectant_chpctm','Coagulant_chpctm']

# %%
for i in tfi2:
    c2[f'Elas_WGI_G{i}'] = c2[i]/c2['WGI_chpctm']
    c2[f'Elas_WQI_{i}'] = c2[i]/c2['WQI_chpctm']
    c2[f'Elas_WGI_c{i}'] = c2[i]/c2['WGI_c_chpctm']
    c2[f'Elas_WGI_d{i}'] = c2[i]/c2['WGI_d_chpctm']

# %%
lmo = [x for x in c2.columns if "Elas_WGI_G" in x]
lmc = [x for x in c2.columns if "Elas_WGI_c" in x]
lmd = [x for x in c2.columns if "Elas_WGI_d" in x]
lmi = [x for x in c2.columns if "Elas_WQI_" in x]
lll = lmo + lmi + lmc + lmd

# %%
mdict = {'Parameters':[],'Median':[],'Count':[],'+ve_inf':[],'-ve_inf':[],'0_count':[]}
for i in lll:
    temp = c2[i].copy()
    temp1 = temp[~temp.isin([np.nan, np.inf, -np.inf,0])]
    mdict['Parameters'].append(i)
    mdict['Median'].append(temp1.median()) ## Get Median due to a good measure when there are outliers
    mdict['Count'].append(temp1.count())
    mdict['+ve_inf'].append(temp[temp.isin([np.inf])].count())
    mdict['-ve_inf'].append(temp[temp.isin([-np.inf])].count())
    mdict['0_count'].append(temp[temp.isin([0])].count())

# %%
result = pd.DataFrame(mdict)
result[result['Parameters'].isin(lmd)]
# Out:
#                        Parameters    Median  Count  +ve_inf  -ve_inf  0_count
# 9    Elas_WGI_dpH Adjuster_chpctm -1.193381    268        4        5        8
# 10  Elas_WGI_dDisinfectant_chpctm -0.326556    267        1        0       42
# 11     Elas_WGI_dCoagulant_chpctm -1.817550    247        3        5       11

# %% [markdown]
# ## Unit Cost Comparison

# %%
uc = pd.read_csv('unit_cost_v2.csv')
uc = uc.rename(columns={'n_wtp':'wtp','UnitCost (cent per m3)':'Unit_cost'})
uc1 = uc[uc['Year']==2021].copy()

# %%
fc = pd.merge(c,uc1[['wtp','Month','Unit_cost']],on=['wtp','Month'],how='left')

# %%
fc.groupby('wtp')[['WGI_d','WQI','Unit_cost']].mean().sort_values(by='WGI_d',ascending=False)
# Out:
#                                      WGI_d        WQI  Unit_cost
# wtp
# Sungai Lolo - Baru               98.574703  94.400000   4.527599
# Sungai Pangsoon                  97.936475  95.154545   3.653661
# Sungai Serai                     97.214430  95.545455  10.487718
# Kalumpang                        95.609502  95.545455   4.865266
# Sungai Rumput                    94.961473  93.736364  16.685140
# Labohan Dagang                   94.711675  90.100000   6.421107
# Sungai Labu                      94.513135  81.863636   2.871870
# Sungai Rangkap                   94.479040  94.490909   4.721915
# Semenyih 2                       94.407652  79.472727   5.699350
# Kepong                           92.796405  94.936364   6.095540
# Batang Kali                      92.367976  90.472727  18.383914
# Sungai Batu                      92.257528  89.700000   2.643524
# Kuala Kubu Bharu                 92.114532  95.863636   4.477614
# Sungai Gombak                    91.969643  94.409091   4.008616
# Rasa                             85.382755  90.181818   0.006989
# Bukit Nanas                      83.048205  71.736364   3.114537
# Salak Tinggi                     77.594106  66.345455   8.571474
# Bukit Tampoi New                 75.722782  73.400000  14.167527
# Sungai Semenyih                  75.634131  74.590909   3.310553
# Wangsa Maju                      75.247232  73.700000   2.763904
# Sungai Dusun                     74.880022  92.572727  10.566502
# Langat 2                         73.636912  92.054545   3.873350
# North Hummock                    72.893398  72.363636  11.085536
# Ampang Intake                    70.508853  92.581818   8.650482
# Sungai Langat                    70.294203  88.418182   4.170874
# Sungai Selangor Fasa 2 Stream C  67.439261  81.672727   4.822555
# Bernam River Headworks (Old)     65.410500        NaN   6.316159
# Bernam River Headworks (New)     64.702473  85.936364        NaN
# Sungai Tengi                     63.526755  92.672727   8.767862
# Sungai Selangor Fasa 3           63.473050  80.972727   0.000000
# Sungai Selisek                   58.333182  88.900000  11.110208
# Cheras Batu 11                   55.119504  74.000000   7.345932
# Sungai Selangor Fasa 1           51.774762  83.754545   1.488503
# Rantau Panjang New               48.910564  84.554545   5.500688
# Rantau Panjang Old               46.555739        NaN        NaN
# Sungai Sireh                     37.005391  83.281818  19.601485
